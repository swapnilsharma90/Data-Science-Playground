# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

file = "csv_files/ca_gov_data/CA_Educational_Attainment___Personal_Income_2008-2014.csv"
d = pd.read_csv(file)

#print(d[["Personal Income"]])

#print(d[["Population Count"]])

pd.DataFrame.hist(d[['Population Count']])
plt.xlabel('Age (years)')
plt.ylabel('count')
plt.show()
